# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time

# %%
def init_browser():
    # ---------------------------------------------------------------------
    # @NOTE: Replace the path with your actual path to the chromedriver
    # executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    #                                            Piruz Alemi Jan 27, 2020
    # ---------------------------------------------------------------------
    executable_path = {"executable_path": "./bin/chromedriver"}
    return Browser("chrome", **executable_path, headless=False)
#init_browser

# %%
def scrape_info():
    browser = init_browser()

    # ------------------------------------------------------------------
    #        Use Splinter to initiate a "visit" to the browser!
    #        And freeze it for 2 seconds!
    #        Use html parser for Soup of this visit
    # -----------------------------------------------------------------
    # Visit visitcostarica.herokuapp.com
    # Visit: https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars
    # url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
    # ---------------------------------------------------------------------
    url = "https://www.jpl.nasa.gov"
    browser.visit(url)

    time.sleep(2)
scrape_info()
# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-33f184b49bc1> in <module>
#      17 scrape_info()
#      18 # Scrape page into Soup
# ---> 19 html = browser.html
#      20 soup = bs(html, "html.parser")
#      21 print(soup)
#
# NameError: name 'browser' is not defined

# %%
# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-deb5d52dfee0> in <module>
#       1 # Scrape page into Soup
# ----> 2 html = browser.html
#       3 soup = bs(html, "html.parser")
#       4 print(soup)
#
# NameError: name 'browser' is not defined

# %%
    # ------------------------------------------------------------------------
    # Get the the videos with mp4 type
    # avg_temps = soup.find('div', id='weather')
    # <source src='/images/exoplanet/20200124/PIA21472.m4v' type='video/mp4'>
    # The code for video was extracted after "inspecting" the website
    # ------------------------------------------------------------------------
    video = soup.find('source', type='video/mp4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d9c5cb16d337> in <module>
#       5 # The code for video was extracted after "inspecting" the website
#       6 # ------------------------------------------------------------------------
# ----> 7 video = soup.find('source', type='video/mp4')
#
# NameError: name 'soup' is not defined

# %%
    # Get the min avg temp
    # min_temp = avg_temps.find_all('strong')[0].text

    # Get the max avg temp
    #max_temp = avg_temps.find_all('strong')[1].text

    # BONUS: Find the src for the sloth image
    relative_image_path = soup.find_all('img')[2]["src"]
    sloth_img = url + relative_image_path

    # Store data in a dictionary
    costa_data = {
        "sloth_img": sloth_img,
        "video": video
    }

    # Close the browser after scraping
    browser.quit()

    # Return results
    return costa_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-64082cbe7e83> in <module>
#       6
#       7 # BONUS: Find the src for the sloth image
# ----> 8 relative_image_path = soup.find_all('img')[2]["src"]
#       9 sloth_img = url + relative_image_path
#      10
#
# NameError: name 'soup' is not defined

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://newjersey.craigslist.org/search/sss?sort=rel&query=guitar'

# %%
# Retrieve page with the requests module
response = requests.get(url)
response.text
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>north jersey for sale &quot;guitar&quot; - craigslist</title>\n\n    <meta name="description" content="north jersey for sale &quot;guitar&quot; - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://newjersey.craigslist.org/search/sss">\n    <link rel="alternate" type="application/rss+xml" href="https://newjersey.craigslist.org/search/sss?format=rss&amp;query=guitar&amp;sort=rel" title="RSS feed for craigslist | north jersey for sale &quot;guitar&quot; - craigslist">\n        <link rel="next" href="https://newjersey.craigslist.org/search/sss?s=120&amp;query=guitar&amp;sort=rel">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=784f71fcd82733e2b32e8d3284beaf58">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.or
# ...

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    north jersey for sale "guitar" - craigslist
#   </title>
#   <meta content='north jersey for sale "guitar" - craigslist' name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://newjersey.craigslist.org/search/sss" rel="canonical"/>
#    <link href="https://newjersey.craigslist.org/search/sss?format=rss&amp;query=guitar&amp;sort=rel" rel="alternate" title='RSS feed for craigslist | north jersey for sale "guitar" - craigslist' type="application/rss+xml"/>
#    <link href="https://newjersey.craigslist.org/search/sss?s=120&amp;query=guitar&amp;sort=rel" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=784f71fcd82733e2b32e8d3284beaf58" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="result-row")
results
# Out:
# [<li class="result-row" data-pid="7064313005" data-repost-of="6979137799">
#  <a class="result-image gallery" data-ids="1:00V0V_6zIPvnvDt41,1:00000_i7bMdO2XEzx,1:00101_65P2Gf3f7Ta,1:00D0D_iRGJm4GhG9o,1:00S0S_5X8RE6v5NS9,1:00A0A_5uW4nSQqGXV" href="https://newjersey.craigslist.org/msg/d/west-milford-vintage-yamaha-solid-state/7064313005.html">
#  <span class="result-price">$85</span>
#  </a>
#  <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2020-01-27 19:30" title="Mon 27 Jan 07:30:24 PM">Jan 27</time>
#  <a class="result-title hdrlnk" data-id="7064313005" href="https://newjersey.craigslist.org/msg/d/west-milford-vintage-yamaha-solid-state/7064313005.html">***** VINTAGE YAMAHA SOLID STATE GUITAR AMPLIFIER *****</a>
#  <span class="result-meta">
#  <span class="result-price">$85</span>
#  <span class="result-hood"> (WEST MILFORD)</span>
# ...

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        # Identify and return price of listing
        price = result.a.span.text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(link)
    except AttributeError as e:
        print(e)
# Out:
# -------------
# ***** VINTAGE YAMAHA SOLID STATE GUITAR AMPLIFIER *****
# $85
# https://newjersey.craigslist.org/msg/d/west-milford-vintage-yamaha-solid-state/7064313005.html
# -------------
# Vintage Harmony H7 Roy Smeck Steel Guitar
# $375
# https://newjersey.craigslist.org/msg/d/succasunna-vintage-harmony-h7-roy-smeck/7055558435.html
# -------------
# Fender Rumble 15 Guitar Amp
# $30
# https://newjersey.craigslist.org/msg/d/verona-fender-rumble-15-guitar-amp/7061272653.html
# -------------
# Vintage VTG Digitech RP-6 Electric Guitar Pedalboard Effects Processor
# $30
# https://newjersey.craigslist.org/app/d/morristown-vintage-vtg-digitech-rp-6/7053705368.html
# -------------
# MXR electric guitar pedals
# $1
# https://newjersey.craigslist.org/msg/d/mountainside-mxr-electric-guitar-pedals/7058935409.html
# -------------
# Set of 4 Guitar Wall Hangers
# $40
# https://newjersey.craigslist.org/msg/d/fairfield-set-of-4-guitar-wall-hangers/7058844153.html
# -------------
# ...

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import os

# %%
# import urllib

# %%
# url = urllib.request.urlopen('https://finance.yahoo.com/quote/SPY/options?p=SPY')

# %%
<span class="Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)" data-reactid="52">323.51</span>

# %%
r = requests.get('https://finance.yahoo.com/quote/SPY/options?p=SPY')

# %%
html = url.read()
html
# Out:
# b'<!DOCTYPE html><html id="atomic" class="NoJs featurephone" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><title>SPDR S&amp;P 500 (SPY) Options Chain - Yahoo Finance</title><meta name="keywords" content="SPY, SPDR S&amp;P 500, SPY options, SPDR S&amp;P 500 options, SPY option chain, SPDR S&amp;P 500 option chain, option, option chain, SPY stock chart, SPDR S&amp;P 500 stock chart, stock chart, stocks, quotes, finance"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta property="twitter:dnt" content="on"/><meta property="fb:app_id" content="90376669494"/><meta name="theme-color" content="#400090"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="description" lang="en-US" content="View the basic SPY option chain and compare options of SPDR S&amp;P 500 on Yahoo Finance."/><meta name="oath:guce:consent-host" conte
# ...

# %%
str_html = str(html)

# %%
# <div class="D(ib) Mend(20px)" data-reactid="51"><span class="Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)" data-reactid="52">323.51</span><span class="Trsdu(0.3s) Fw(500) Pstart(10px) Fz(24px) C($dataRed)" data-reactid="53">-5.26 (-1.60%)</span><div id="quote-market-notice" class="C($tertiaryColor) D(b) Fz(12px) Fw(n) Mstart(0)--mobpsm Mt(6px)--mobpsm" data-reactid="54"><span data-reactid="55">At close:  4:00PM EST</span></div></div>

# %%
str_html.find('data-reactid="52"')
# Out:
# 35237

# %%
str_html.find("Fw(b)")
# Out:
# 24657

# %%
str_html[35237:]
# Out:
# 'data-reactid="52">Volume</span><!-- react-text: 53 --><!-- /react-text --></th><th class="Va(b) Py(4px) Fw(400) Fz(xs) Ta(end) Pstart(7px) C($tertiaryColor)" data-reactid="54"><span data-reactid="55">Open Interest</span><!-- react-text: 56 --><!-- /react-text --></th><th class="Va(b) Py(4px) Fw(400) Fz(xs) Ta(end) Pstart(7px) Pend(6px) C($tertiaryColor)" data-reactid="57"><span data-reactid="58">Implied Volatility</span><!-- react-text: 59 --><!-- /react-text --></th></tr></thead><tbody data-reactid="60"><tr class="data-row0 Bgc($hoverBgColor):h BdT Bdc($seperatorColor) H(33px) in-the-money Bgc($hoverBgColor) Whs(nw)" data-reactid="61"><td class="data-col0 Ta(start) Pstart(10px) Bdstartw(8px) Bdstarts(s) Bdstartc(t) in-the-money_Bdstartc($linkColor)" data-reactid="62"><a href="/quote/SPY200129C00280000?p=SPY200129C00280000" class="Fz(s) Ell C($linkColor)" data-reactid="63">SPY200129C00280000</a></td><td class="data-col1 Ta(end) Pstart(7px)" data-reactid="64">2020-01-06 12:15PM EST</
# ...

# %%
url.close()

# %%
# html_soup = BeautifulSoup(html, "html.parser")
html_soup = BeautifulSoup(r.text, 'html.parser')

# %%
data = html_soup.find_all("span", {"class":"Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)"})

# %%
print(data)
# Out:
# []

# %%
print(html_soup.find("span", {"class":"Trsdu(0.3s) Fw(b) Fz(36px) Mb(-4px) D(ib)"}))
# Out:
# None

# %%
import pandas as pd

# %%
df = pd.read_html('https://finance.yahoo.com/quote/SPY/history?p=SPY')[0]
df[:-1]
# Out:
#             Date    Open    High     Low  Close* Adj Close**    Volume
# 0   Jan 27, 2020  323.03  325.12  322.66  323.50      323.50  83877900
# 1   Jan 24, 2020  332.44  332.53  327.36  328.77      328.77  87578400
# 2   Jan 23, 2020  330.63  332.17  329.41  331.72      331.72  51963000
# 3   Jan 22, 2020  332.24  332.95  331.17  331.34      331.34  48914900
# 4   Jan 21, 2020  330.90  332.18  330.82  331.30      331.30  77742400
# ..           ...     ...     ...     ...     ...         ...       ...
# 94  Sep 13, 2019  301.78  302.17  300.68  301.09      298.24  62104800
# 95  Sep 12, 2019  301.25  302.46  300.41  301.29      298.44  72908700
# 96  Sep 11, 2019  298.47  300.34  297.75  300.25      297.41  68821100
# 97  Sep 10, 2019  297.36  298.20  295.97  298.13      295.31  57947100
# 98  Sep 09, 2019  299.14  299.24  297.16  298.20      295.38  51260300
#
# [99 rows x 7 columns]

# %%
# Out:
#                                                   Date  \
# 0                                         Jan 27, 2020
# 1                                         Jan 24, 2020
# 2                                         Jan 23, 2020
# 3                                         Jan 22, 2020
# 4                                         Jan 21, 2020
# ..                                                 ...
# 96                                        Sep 11, 2019
# 97                                        Sep 10, 2019
# 98                                        Sep 09, 2019
# 99                                        Sep 06, 2019
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                               323.03
# 1                                               332.44
# 2                                               330.63
# 3                                               332.24
# ...

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time

# %%
def init_browser():
    # ---------------------------------------------------------------------
    # @NOTE: Replace the path with your actual path to the chromedriver
    # executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    #                                            Piruz Alemi Jan 27, 2020
    # ---------------------------------------------------------------------
    executable_path = {"executable_path": "./bin/chromedriver"}
    return Browser("chrome", **executable_path, headless=False)
init_browser
# Out:
# <function __main__.init_browser()>

# %%
#def scrape_info():
browser = init_browser()

# ------------------------------------------------------------------
#        Use Splinter to initiate a "visit" to the browser!
#        And freeze it for 2 seconds!
#        Use html parser for Soup of this visit
# -----------------------------------------------------------------
# Visit visitcostarica.herokuapp.com
# Visit: https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars
# url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
# url = "https://www.jpl.nasa.gov"
url = "https://www.jpl.nasa.gov/news/"
browser.visit(url)

time.sleep(2)

# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")
print(soup)
# Out:
# <html class="js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths -webkit-" style=""><!-- START HEADER: "DEFAULT" --><!-- Google Tag Manager --><head><script src="https://m.addthis.com/live/red_lojson/300lo.json?si=5e2f9dc404c9ad17&amp;bkl=0&amp;bl=1&amp;pdt=611&amp;sid=5e2f9dc404c9ad17&amp;pub=&amp;rev=v8.28.3-wp&amp;ln=en&amp;pc=men&amp;cb=0&amp;ab=-&amp;dp=www.jpl.nasa.gov&amp;fp=news%2F&amp;fr=&amp;of=1&amp;pd=0&amp;irt=0&amp;vcl=0&amp;md=0&amp;ct=1&amp;tct=0&amp;abt=0&amp;cdn=0&amp;pi=1&amp;rb=0&amp;gen=100&amp;chr=UTF-8&amp;mk=NASA%2CJPL%2CJet%20Propulsion%20Laboratory%2CNews%2CInteractiv
# ...

# %%
# ------------------------------------------------------------------------
# Get the the videos with mp4 type
# avg_temps = soup.find('div', id='weather')
# <source src='/images/exoplanet/20200124/PIA21472.m4v' type='video/mp4'>
# The code for video was extracted after "inspecting" the website
# ------------------------------------------------------------------------
# video = soup.find('source', type='video/mp4')
c = soup.find('<p>')
# Get the min avg temp
# min_temp = avg_temps.find_all('strong')[0].text
print(c)
# Out:
# None

# %%
result = soup.find_all('div', {'class':'content_title'})

# %%
len(result)
# Out:
# 27

# %%
result[0]
# Out:
# <div class="content_title">
# 									  Irvine School Wins Regional Science Bowl at JPL Third Year in a Row
# 									</div>

# %%
output = []
for i in range(len(result)):
    output.append(result[i].text)
print(output[0])
# Out:
# 									  Irvine School Wins Regional Science Bowl at JPL Third Year in a Row

# %%
print(soup.title.contents)
# Out:
# ['Space Mission and Science News | NASA Jet Propulsion Laboratory']

# %%
title = soup.title.string
title_content=soup.title.contents[0]
paragraph_content=soup.p.contents[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-f2e76993ef00> in <module>
#       2
#       3 title_content=soup.title.contents[0]
# ----> 4 paragraph_content=soup.p.contents[0]
#
# AttributeError: 'NoneType' object has no attribute 'contents'

# %%
title_content
# Out:
# 'NASA Jet Propulsion Laboratory (JPL) - Space Mission and Science News, Videos and Images'

# %%
    
    # ------------------------------------------------------
    #      How to load a list of href  into the dictionary?
    #      Gets all href
    # -----------------------------------------------------
    for link in soup.find_all('a'):
        links=link.get('href')
    # ------------------------------------------------------
    #       Gets all the texts
    # ------------------------------------------------------
    text=soup.get_text()
    # Get the max avg temp
    #max_temp = avg_temps.find_all('strong')[1].text

    # BONUS: Find the src for nasa images
    relative_image_path = soup.find_all('img')[2]["src"]
    # nasa_img = url + relative_image_path
    nasa_img = relative_image_path

    # Store data in a nasa dictionary
    nasa_data = {
        "nasa_img": nasa_img,
        "Title": title_content,
        "Text": text,
        "Links": links,
        "paragraph": paragraph_content

    }

    # Close the browser after scraping
    browser.quit()

    # Return results
    return nasa_data

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
stocks = pd.read_csv("spy.csv") 
# Preview the first 5 lines of the loaded data

# %%
stocks.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-01-29  263.920013  264.549988  262.480011  263.410004  258.514801
# 1  2019-01-30  265.100006  268.519989  264.250000  267.579987  262.607300
# 2  2019-01-31  267.510010  270.470001  267.269989  269.929993  264.913605
# 3  2019-02-01  270.149994  271.200012  269.179993  270.059998  265.041229
# 4  2019-02-04  270.109985  272.029999  269.359985  271.959991  266.905884
#
#       Volume
# 0   66136300
# 1   92473700
# 2  104012100
# 3   85782500
# 4   60744800

# %%
stocks[:-1]
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-01-29  263.920013  264.549988  262.480011  263.410004  258.514801
# 1    2019-01-30  265.100006  268.519989  264.250000  267.579987  262.607300
# 2    2019-01-31  267.510010  270.470001  267.269989  269.929993  264.913605
# 3    2019-02-01  270.149994  271.200012  269.179993  270.059998  265.041229
# 4    2019-02-04  270.109985  272.029999  269.359985  271.959991  266.905884
# ..          ...         ...         ...         ...         ...         ...
# 246  2020-01-21  330.899994  332.179993  330.820007  331.299988  331.299988
# 247  2020-01-22  332.239990  332.950012  331.170013  331.339996  331.339996
# 248  2020-01-23  330.630005  332.170013  329.410004  331.720001  331.720001
# 249  2020-01-24  332.440002  332.529999  327.359985  328.769989  328.769989
# 250  2020-01-27  323.029999  325.119995  322.660004  323.500000  323.500000
#
#         Volume
# 0     66136300
# 1     92473700
# ...

# %%
stocks["Date"]
# Out:
# 0      2019-01-29
# 1      2019-01-30
# 2      2019-01-31
# 3      2019-02-01
# 4      2019-02-04
#           ...
# 247    2020-01-22
# 248    2020-01-23
# 249    2020-01-24
# 250    2020-01-27
# 251    2020-01-28
# Name: Date, Length: 252, dtype: object

# %%
options=pd.read_html("https://finance.yahoo.com/quote/SPY/options?p=SPY")
print(options)
# Out:
# [         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   SPY200129C00280000  2020-01-06 12:15PM EST   280.0       42.65  46.94
# 1   SPY200129C00300000   2020-01-27 3:42PM EST   300.0       27.00  26.95
# 2   SPY200129C00301000   2020-01-27 3:41PM EST   301.0       22.96  26.02
# 3   SPY200129C00302000   2020-01-10 9:37AM EST   302.0       25.25  24.95
# 4   SPY200129C00303000   2020-01-28 1:05PM EST   303.0       23.84  23.98
# 5   SPY200129C00305000  2020-01-28 10:25AM EST   305.0       21.44  21.98
# 6   SPY200129C00308000   2020-01-24 2:58PM EST   308.0       18.84  18.98
# 7   SPY200129C00309000   2020-01-27 9:50AM EST   309.0       15.69  18.03
# 8   SPY200129C00310000  2020-01-28 11:22AM EST   310.0       16.84  16.99
# 9   SPY200129C00312000   2020-01-21 3:36PM EST   312.0       19.57  15.04
# 10  SPY200129C00314000   2020-01-28 2:11PM EST   314.0       13.31  12.99
# 11  SPY200129C00315000  2020-01-28 11:21AM EST   315.0       11.93  12.01
# ...

# %%
options[0].head()
# Out:
#         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0  SPY200129C00280000  2020-01-06 12:15PM EST   280.0       42.65  46.94
# 1  SPY200129C00300000   2020-01-27 3:42PM EST   300.0       27.00  26.95
# 2  SPY200129C00301000   2020-01-27 3:41PM EST   301.0       22.96  26.02
# 3  SPY200129C00302000   2020-01-10 9:37AM EST   302.0       25.25  24.95
# 4  SPY200129C00303000   2020-01-28 1:05PM EST   303.0       23.84  23.98
#
#      Ask  Change % Change Volume  Open Interest Implied Volatility
# 0  47.19    0.00        -      -            252            146.29%
# 1  27.15    2.94  +12.22%      -              4             87.50%
# 2  26.09    0.00        -      -             10             85.16%
# 3  25.14    0.00        -      2              3             81.45%
# 4  24.12   -1.85   -7.20%      1              1             78.91%

# %%
#options[:-1]

# %%
options_df=options[0][["Contract Name","Bid","Strike","Last Price", "Last Trade Date", "Implied Volatility"]]
#Bid=options[0][["Bid"]]
#Bid
options_df.head()
# Out:
#         Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0  SPY200129C00280000  46.94   280.0       42.65  2020-01-06 12:15PM EST
# 1  SPY200129C00300000  26.95   300.0       27.00   2020-01-27 3:42PM EST
# 2  SPY200129C00301000  26.02   301.0       22.96   2020-01-27 3:41PM EST
# 3  SPY200129C00302000  24.95   302.0       25.25   2020-01-10 9:37AM EST
# 4  SPY200129C00303000  23.98   303.0       23.84   2020-01-28 1:05PM EST
#
#   Implied Volatility
# 0            146.29%
# 1             87.50%
# 2             85.16%
# 3             81.45%
# 4             78.91%

# %%
options_df["DateTime"] = options_df["Last Trade Date"]
DateTime.head()
# Out:
# /Users/piruzalemi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0    2020-01-06 12:15PM EST
# 1     2020-01-27 3:42PM EST
# 2     2020-01-27 3:41PM EST
# 3     2020-01-10 9:37AM EST
# 4     2020-01-28 1:05PM EST
# Name: Last Trade Date, dtype: object

# %%
df = options_df.DateTime.str.split(expand=True)   
df.columns = ['Date', 'Time', 'place']

# %%
df.head()
# Out:
#          Date     Time place
# 0  2020-01-06  12:15PM   EST
# 1  2020-01-27   3:42PM   EST
# 2  2020-01-27   3:41PM   EST
# 3  2020-01-10   9:37AM   EST
# 4  2020-01-28   1:05PM   EST

# %%
options_df['Date'] = df["Date"]
# Out:
# /Users/piruzalemi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
options_df.head()
# Out:
#         Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0  SPY200129C00280000  46.94   280.0       42.65  2020-01-06 12:15PM EST
# 1  SPY200129C00300000  26.95   300.0       27.00   2020-01-27 3:42PM EST
# 2  SPY200129C00301000  26.02   301.0       22.96   2020-01-27 3:41PM EST
# 3  SPY200129C00302000  24.95   302.0       25.25   2020-01-10 9:37AM EST
# 4  SPY200129C00303000  23.98   303.0       23.84   2020-01-28 1:05PM EST
#
#   Implied Volatility                DateTime        Date
# 0            146.29%  2020-01-06 12:15PM EST  2020-01-06
# 1             87.50%   2020-01-27 3:42PM EST  2020-01-27
# 2             85.16%   2020-01-27 3:41PM EST  2020-01-27
# 3             81.45%   2020-01-10 9:37AM EST  2020-01-10
# 4             78.91%   2020-01-28 1:05PM EST  2020-01-28

# %%
stocks.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-01-29  263.920013  264.549988  262.480011  263.410004  258.514801
# 1  2019-01-30  265.100006  268.519989  264.250000  267.579987  262.607300
# 2  2019-01-31  267.510010  270.470001  267.269989  269.929993  264.913605
# 3  2019-02-01  270.149994  271.200012  269.179993  270.059998  265.041229
# 4  2019-02-04  270.109985  272.029999  269.359985  271.959991  266.905884
#
#       Volume
# 0   66136300
# 1   92473700
# 2  104012100
# 3   85782500
# 4   60744800

# %%
stockOption=pd.merge(options_df, stocks, on='Date', how='left')
stockOption
# Out:
#          Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0   SPY200129C00280000  46.94   280.0       42.65  2020-01-06 12:15PM EST
# 1   SPY200129C00300000  26.95   300.0       27.00   2020-01-27 3:42PM EST
# 2   SPY200129C00301000  26.02   301.0       22.96   2020-01-27 3:41PM EST
# 3   SPY200129C00302000  24.95   302.0       25.25   2020-01-10 9:37AM EST
# 4   SPY200129C00303000  23.98   303.0       23.84   2020-01-28 1:05PM EST
# 5   SPY200129C00305000  21.98   305.0       21.44  2020-01-28 10:25AM EST
# 6   SPY200129C00308000  18.98   308.0       18.84   2020-01-24 2:58PM EST
# 7   SPY200129C00309000  18.03   309.0       15.69   2020-01-27 9:50AM EST
# 8   SPY200129C00310000  16.99   310.0       16.84  2020-01-28 11:22AM EST
# 9   SPY200129C00312000  15.04   312.0       19.57   2020-01-21 3:36PM EST
# 10  SPY200129C00314000  12.99   314.0       13.31   2020-01-28 2:11PM EST
# 11  SPY200129C00315000  12.01   315.0       11.93  2020-01-28 11:21AM EST
# ...

# %%
import matplotlib.pyplot as plt

# %%
 stockOption.plot(x="Date", y=['Strike'], stacked=True, kind="bar")
 ax = stockOption['Volume'].plot(secondary_y=True, color='k', marker='o', figsize=(20,10))
 ax.set_ylabel('Volume')

 plt.show()

# %%
lines = stockOption.plot.line(x='Bid', y=['Volume', 'Open'], figsize=(20,10))

# %%
lines = stockOption.plot.line(x='Bid', y=['Strike', 'Open'], figsize=(20,10))

# %%
lines = stockOption.plot.line(x='Date', y='Open', figsize=(20,10))

# %%
lines = stockOption.plot.line(x='Date', y='Last Price', figsize=(20,10))

# %%
stockOption['IV'] =stockOption['Implied Volatility'].str.slice(0, -1)
stockOption.head()
# Out:
#         Contract Name    Bid  Strike  Last Price         Last Trade Date  \
# 0  SPY200129C00280000  46.94   280.0       42.65  2020-01-06 12:15PM EST
# 1  SPY200129C00300000  26.95   300.0       27.00   2020-01-27 3:42PM EST
# 2  SPY200129C00301000  26.02   301.0       22.96   2020-01-27 3:41PM EST
# 3  SPY200129C00302000  24.95   302.0       25.25   2020-01-10 9:37AM EST
# 4  SPY200129C00303000  23.98   303.0       23.84   2020-01-28 1:05PM EST
#
#   Implied Volatility                DateTime        Date        Open  \
# 0            146.29%  2020-01-06 12:15PM EST  2020-01-06  320.489990
# 1             87.50%   2020-01-27 3:42PM EST  2020-01-27  323.029999
# 2             85.16%   2020-01-27 3:41PM EST  2020-01-27  323.029999
# 3             81.45%   2020-01-10 9:37AM EST  2020-01-10  327.290009
# 4             78.91%   2020-01-28 1:05PM EST  2020-01-28  325.059998
#
#          High         Low       Close   Adj Close    Volume IV_substring  \
# ...

# %%
stockOption['IV%'] = stockOption['IV'].apply(pd.to_numeric, errors='coerce')

# %%
#stockOption.plot()
stockOption.plot.line(x='Date', y=['IV%', 'Strike'], figsize=(20,10) )
#stockOption.plot()
plt.show()

# %%
#s = stockOption["Bid", "Open", "High"]
#s.plot.line()

# %%
df = pd.DataFrame({
   'Bid': [stockOption['Bid']],
    'Strike': [stockOption['Strike']]
    }, index=stockOption['Date'])
lines = df.plot.line(figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-222-3070268b75ec> in <module>
#       3     'Strike': [stockOption['Strike']]
#       4     }, index=stockOption['Date'])
# ----> 5 lines = df.plot.line(figsize=(20,10))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#     861             >>> lines = df.plot.line(x='pig', y='horse')
#     862         """
# --> 863         return self(kind="line", x=x, y=y, **kwargs)
#     864
#     865     def bar(self, x=None, y=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ...

# %%
export_csv = stockOption.to_csv (r'.//export_dataframe.csv')
export_csv

# %%
print(export_csv)
# Out:
# None
